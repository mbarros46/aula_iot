# %% [markdown]
# # Rede_Neuronal
#
# Aluno: mig
# Descrição: Versão refatorada para estudo — nomes padronizados e comentários ajustados.

# %%
#rede_perceptron
import math
input = 1
output_desejado = 0
weight = 0.5
learnning_rate = 0.01

def activation(calculo_aprendizado):
  if calculo_aprendizado >= 0:
    return 1
  else:
    return 0

error = math.inf
iteration = 0
output = 0

#etapa 3 apos o calculo de input 0
bias = 1
bias_weight = 0.5

while not error == 0:
  iteration +=1
  print("=====Iteração: ", iteration, "=====")
  calculo_aprendizado = (input * weight)# + (bias * bias_weight)
  output = activation(calculo_aprendizado)
  print("calculo: ", calculo_aprendizado)
  print("Entrada: ", input, "Desejado: ", output_desejado)

  print("Saida: ", output, "Erro: ", error)
  error = output_desejado - output

  if not error == 0:
    weight = weight + (learnning_rate * input * error)
    bias_weight = (bias_weight * learnning_rate * error)
    print("weight: ", weight, "")
print("A rede aprendeu!!!")
# Out:
# =====Iteração:  1
# calculo:  0.5
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  inf
# weight:  0.49
# =====Iteração:  2
# calculo:  0.49
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  -1
# weight:  0.48
# =====Iteração:  3
# calculo:  0.48
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  -1
# weight:  0.47
# =====Iteração:  4
# calculo:  0.47
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  -1
# weight:  0.45999999999999996
# =====Iteração:  5
# calculo:  0.45999999999999996
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  -1
# weight:  0.44999999999999996
# =====Iteração:  6
# calculo:  0.44999999999999996
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  -1
# weight:  0.43999999999999995
# =====Iteração:  7
# calculo:  0.43999999999999995
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  -1
# weight:  0.42999999999999994
# =====Iteração:  8
# calculo:  0.42999999999999994
# Entrada:  1 Desejado:  0
# Saida:  1 Erro:  -1
# weight:  0.41999999999999993
# =====Iteração:  9
# ...
